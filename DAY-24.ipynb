# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the data
cars=pd.read_csv(r"C:\Users\kosun\Downloads\Cars.csv")
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
cars.isna().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %% [raw]
# displot
# boxplot
# scatter plot

# %%
import seaborn as sns
sns.displot(cars['HP'])

# %%
sns.displot(cars['SP'])

# %%
sns.displot(cars['MPG'])

# %%
sns.displot(cars['WT'])

# %%
sns.distplot(x=cars['WT'])
plt.title('Distribution of weight of vehicles in thousand pounds')
plt.xlabel('Weight in Thousand pounds')
plt.show()
# Out:
# C:\Users\kosun\AppData\Local\Temp\ipykernel_9820\3012159432.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=cars['WT'])

# %%
sns.boxplot(x=cars['HP'])
plt.show()

# %%
sns.boxplot(x=cars['MPG'])
# Out:
# <Axes: xlabel='MPG'>

# %%
sns.boxplot(x=cars['WT'])
# Out:
# <Axes: xlabel='WT'>

# %%
sns.boxplot(x=cars['SP'])
# Out:
# <Axes: xlabel='SP'>

# %%
from seaborn import scatterplot

scatterplot(x=cars['VOL'],y=cars['MPG'])
# Out:
# <Axes: xlabel='VOL', ylabel='MPG'>

# %%
scatterplot(x=cars['VOL'],y=cars['SP'])
# Out:
# <Axes: xlabel='VOL', ylabel='SP'>

# %%
scatterplot(x=cars['VOL'],y=cars['WT'])
# Out:
# <Axes: xlabel='VOL', ylabel='WT'>

# %%
sns.barplot(x=cars['HP'],y=cars['VOL'])
# Out:
# <Axes: xlabel='HP', ylabel='VOL'>

# %%
sns.barplot(x=cars['MPG'],y=cars['VOL'])
# Out:
# <Axes: xlabel='MPG', ylabel='VOL'>

# %%
sns.barplot(x=cars['HP'],y=cars['SP'])
# Out:
# <Axes: xlabel='HP', ylabel='SP'>

# %%
sns.barplot(x=cars['HP'],y=cars['WT'])
# Out:
# <Axes: xlabel='HP', ylabel='WT'>

# %%
sns.barplot(x=cars['HP'],y=cars['MPG'])
# Out:
# <Axes: xlabel='HP', ylabel='MPG'>

# %%
scatterplot(x=cars['HP'],y=cars['SP'])
# Out:
# <Axes: xlabel='HP', ylabel='SP'>

# %%
scatterplot(x=cars['HP'],y=cars['MPG'])
# Out:
# <Axes: xlabel='HP', ylabel='MPG'>

# %%
scatterplot(x=cars['HP'],y=cars['WT'])
# Out:
# <Axes: xlabel='HP', ylabel='WT'>

# %%
scatterplot(x=cars['VOL'],y=cars['SP'])
# Out:
# <Axes: xlabel='VOL', ylabel='SP'>

# %%
scatterplot(x=cars['WT'],y=cars['SP'])
# Out:
# <Axes: xlabel='WT', ylabel='SP'>

# %%
scatterplot(x=cars['WT'],y=cars['SP'])
# Out:
# <Axes: xlabel='WT', ylabel='SP'>

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
cars[['HP','WT','SP','VOL']]=sc.fit_transform(cars[['HP','WT','VOL','SP']])

# %%
np.round(cars.describe(),3)
# Out:
#            HP     MPG     VOL      SP      WT
# count  81.000  81.000  81.000  81.000  81.000
# mean   -0.000  34.422   0.000   0.000   0.000
# std     1.006   9.131   1.006   1.006   1.006
# min    -1.206  12.101  -1.559  -2.200  -2.243
# 25%    -0.590  27.856  -0.547  -0.441  -0.379
# 50%    -0.308  35.153  -0.236   0.101   0.043
# 75%     0.397  39.532   0.345   0.642   0.669
# max     3.603  53.701   3.410   2.763   2.764

# %%
import statsmodels.formula.api as smf
ml_v=smf.ols('MPG~VOL',data = cars).fit()
ml_v.rsquared
# Out:
# 0.4721402334141217

# %%
ml_v.params
# Out:
# Intercept    34.422076
# VOL          -6.235589
# dtype: float64

# %%
ml_w=smf.ols('MPG~WT',data = cars).fit()
np.round(ml_w.rsquared)
# Out:
# 0.0

# %%
ml_hp=smf.ols('MPG~HP',data = cars).fit()
ml_hp.rsquared
# Out:
# 0.5256806086282022

# %%
import statsmodels.formula.api as smf
model = smf.ols('MPG~WT+VOL+SP+HP',data=cars_df).fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 2
#       1 import statsmodels.formula.api as smf
# ----> 2 model = smf.ols('MPG~WT+VOL+SP+HP',data=cars_df).fit()
#
# NameError: name 'cars_df' is not defined
